# %% [markdown]
# ### Creating an Array

# %%
intergerArray=[1,1,2,3,5]
print(intergerArray)
# Out:
# [1, 1, 2, 3, 5]

# %%
charArray=['a' for j in range(100)]
print(charArray)
# Out:
# ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']

# %%
booleArray=[False]*32768
print(booleArray)
# Out:
# [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, Fal
# ...

# %%
maxSize=10000
myArray=[None]*maxSize
myArraySize=0

# %% [markdown]
# ### Accessing List Elements

# %%
temp=myArray[3] #get contents of fourth element of array
print(temp)
# Out:
# None

# %%
myArray[7]=66 #insert 66 into the eighth cell.

# %% [markdown]
# #### An Array Class Example: BadArray

# %%
class Array(object):

    def __init__(self,initialSize):           # Constructor
        self.__a=[None]*initialSize           # The array stord as a list
        self.nItems=0                         # No item in array initially

    def insert(self,item):                    # Insert item at end
        self.__a[self.nItems]=item            # Item goes at current end
        self.nItems=self.nItems+1             #Increment number of items

    def search(self,item):
        for j in range(self.nItems):
            if self.__a[j]==item:
                return self.__a[j]
        return None

    def delete(self, item):
        for j in range(self.nItems):
            if self.__a[j]==item:
                for k in range(j,self.nItems):
                    self.__a[k]=self.__a[k+1]
                self.nItems=self.nItems-1
                return Ture
        return False

    def traverse(self, function=print):
        for j in range(self.nItems):
            function(self.__a[j])

# %%
maxSize=10               # Max size of the Array
arr=Array(maxSize)       # Create an Array Object

# %%
arr.insert(77)
arr.insert(99)
arr.insert("foo")
arr.insert("Bar")
arr.insert(44)
arr.insert(55)
arr.insert(12.34)
arr.insert(0)
arr.insert("baz")
arr.insert(-17)

# %%
print("Array containing",arr.nItems,"items")
arr.traverse()
# Out:
# Array containing 10 items
# 77
# 99
# foo
# Bar
# 44
# 55
# 12.34
# 0
# baz
# -17

# %%
print("Search for 12 return",arr.search(12))
# Out:
# Search for 12 return None

# %%
print("Search for 12.34 return", arr.search(12.34))
# Out:
# Search for 12.34 return 12.34

# %%
print("Deleting 0 return",arr.delete(0))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 print("Deleting 0 return",arr.delete(0))
#
# Cell In[26], line 21, in Array.delete(self, item)
#      19 if self.__a[j]==item:
#      20     for k in range(j,self.nItems):
# ---> 21         self.__a[k]=self.__a[k+1]
#      22     self.nItems=self.nItems-1
#      23     return Ture
#
# IndexError: list index out of range

# %% [markdown]
# ### A Better Array Class Implementation

# %%
class Array(object):

    def __init__(self,initialSize):
        self.__a=[None]*initialSize
        self.__nItems=0

    def __len__(self):
        return self.__nItems

    def get(self,n):
        if 0<=n and n<self.__nItems:
            return self.__a[n]

    def set(self,n,value):
        if 0<=n and n<self.__nItems:
            self.__a[n]=value

    def insert(self,item):
        self.__a[self.__nItems]=item
        self.__nItems=self.__nItems+1

    def find(self,item):
        for j in range(self.__nItems):
            if self.__a[j]==item:
                return j
        return -1

    def search(self,item):
        return self.get(self.find(item))

    def delete(self, item):
        for j in range(self.__nItems):
            if self.__a[j]==item:
                self.__nItems=self.__nItems-1
                for k in range(j, self.__nItems):
                    self.__a[k]=self.__a[k+1]
                return True
        return False

    def traverse(self,function=print):
        for j in range(self.__nItems):
            function(self.__a[j])

# %%
maxSize=10               # Max size of the Array
arr=Array(maxSize)

# %%
arr.insert(77)
arr.insert(99)
arr.insert("foo")
arr.insert("Bar")
arr.insert(44)
arr.insert(55)
arr.insert(12.34)
arr.insert(0)
arr.insert("baz")
arr.insert(-17)

# %%
print("Array containing",len(arr),"items")
# Out:
# Array containing 10 items

# %%
arr.traverse()
# Out:
# 77
# 99
# foo
# Bar
# 44
# 55
# 12.34
# 0
# baz
# -17

# %%
print("Search for 12 return",arr.search(12))
# Out:
# Search for 12 return None

# %%
print("Search for 12.34 return",arr.search(12.34))
# Out:
# Search for 12.34 return 12.34

# %%
print("Delect 0 return",arr.delete(0))
# Out:
# Delect 0 return True

# %%
print("Delect 17 returns",arr.delete(17))
# Out:
# Delect 17 returns False

# %%
print("setting item at index 3 to 33")
arr.set(3,33)
# Out:
# setting item at index 3 to 33

# %%
print("Array after deletions has", len(arr),"items")
arr.traverse()
# Out:
# Array after deletions has 9 items
# 77
# 99
# foo
# 33
# 44
# 55
# 12.34
# baz
# -17

# %% [markdown]
# ### An OrderedArray Class

# %% [markdown]
# #### Basic OrderedArray Class Definition

# %%
class OrderedArray(object):

    def __init__(self,initialSize):
        self.__a=[None]*initialSize
        self.__nItems=0

    def __len__(self):
        return self.__nItems

    def get(self,n):
        if 0<=n and n<self.__nItems:
            return self.__a[n]
        return IndexError("Index "+str(n)+" is out of range")

    def traverse(self,function=print):
        for j in range(self.__nItems):
            function(self.__a[j])

    def __str__(self):
        ans="["
        for i in range(self.__nItems):
            if len(ans)>1:
                ans+=", "
            ans += str(self.__a[i])
        ans+="]"
        return ans

# %%
class OrderedArray(object):

    def __init__(self,initialSize):
        self.__a=[None]*initialSize
        self.__nItems=0

    def __len__(self):
        return self.__nItems

    def get(self,n):
        if 0<=n and n<self.__nItems:
            return self.__a[n]
        return IndexError("Index "+str(n)+" is out of range")

    def traverse(self,function=print):
        for j in range(self.__nItems):
            function(self.__a[j])

    def __str__(self):
        ans="["
        for i in range(self.__nItems):
            if len(ans)>1:
                ans+=", "
            ans += str(self.__a[i])
        ans+="]"
        return ans

    def find(self,item):
        lo=0
        hi=self.__nItems-1

        while lo<=hi:
            mid=(lo+hi)//2
            if self.__a[mid}==item):
                return mid
            elif self.__a[mid]<item:
                lo=mid+1
            else:
                hi=mid-1
        return lo

    def search(self,item):
        index=self.find(item)
        if index<self.__nItems and self.__a[index]==item:
            return self.__a[index]

    def insert(self,item):
        if self.__nItems>=len(self.__a):
            raise Exception("Array overflow")
        index=self.find(item)
        for j in range(self.__nItems,index,-1):
            self.__a[j]=self.__a[j-1]

        self.__a[index]=item
        self.__nItems+=1

    def delete(self,item):
        j=self.find(item)
        if j<self.__nItems and self.__a[j] ==item:
            self.__nItems -= 1
            for k in range(j,self.__nItems):
                self.__a[k]=self.__a[k+1]
            return True
        return False
